# %%
import sys
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time
import itertools
import random

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import keras
from keras import models
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate, Dropout
from keras.models import Model

from keras.layers import BatchNormalization

from keras.layers import MaxPooling2D

from keras.layers import concatenate

from keras.layers import Lambda, Flatten, Dense

from keras.initializers import glorot_uniform

from tensorflow.keras.layers import Layer, InputSpec
from tensorflow.keras.regularizers import l2

import keras.backend as K

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# !unzip Hindi.zip
# Out:
# Archive:  Hindi.zip
# replace Hindi/001/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
path_hindi = "/content/Hindi/"

# %%
# Get the list of all directories and sort them
dir_list = next(os.walk(path_hindi))[1]
dir_list.sort()

# %%
data_groups = []
for directory in dir_list:
    images = os.listdir(path_hindi+directory)
    images.sort()
    images = [path_hindi+directory+'/'+x for x in images]
    data_groups.append(images)

# %%
# !unzip Bengali.zip
# Out:
# Archive:  Bengali.zip
#    creating: Bengali/001/
#   inflating: Bengali/001/.DS_Store
#   inflating: Bengali/001/B-S-1-F-01.tif
#   inflating: Bengali/001/B-S-1-F-02.tif
#   inflating: Bengali/001/B-S-1-F-03.tif
#   inflating: Bengali/001/B-S-1-G-01.tif
#   inflating: Bengali/001/B-S-1-G-02.tif
#   inflating: Bengali/001/B-S-1-G-03.tif

# %%
path_bengali = "/content/Bengali/"

# %%
dir_list = next(os.walk(path_bengali))[1]
dir_list.sort()

# %%
for directory in dir_list:
    images = os.listdir(path_bengali+directory)
    images.sort()
    images = [path_bengali+directory+'/'+x for x in images]
    data_groups.append(images)

# %%
len(data_groups)
# Out:
# 2

# %%
data_lengths = [len(x) for x in data_groups]
print(data_lengths)
# Out:
# [7, 7]

# %% [markdown]
# **Train Validation Test Split**

# %%
train, test = train_test_split(data_groups, test_size=0.04, train_size=0.96, random_state=1)
train, val = train_test_split(train, test_size=0.04, train_size=0.96, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-1173e5a40ca3> in <cell line: 2>()
#       1 train, test = train_test_split(data_groups, test_size=0.04, train_size=0.96, random_state=1)
# ----> 2 train, val = train_test_split(train, test_size=0.04, train_size=0.96, random_state=1)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
# -> 2562     n_train, n_test = _validate_shuffle_split(
#    2563         n_samples, test_size, train_size, default_test_size=0.25
#    2564     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2234
#    2235     if n_train == 0:
# -> 2236         raise ValueError(
#    2237             "With n_samples={}, test_size={} and train_size={}, the "
#    2238             "resulting train set will be empty. Adjust any of the "
#
# ValueError: With n_samples=1, test_size=0.04 and train_size=0.96, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
train_size = len(train)
test_size = len(test)
val_size = len(val)
print(len(train), len(val), len(test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-4a82f3ac531a> in <cell line: 3>()
#       1 train_size = len(train)
#       2 test_size = len(test)
# ----> 3 val_size = len(val)
#       4 print(len(train), len(val), len(test))
#
# NameError: name 'val' is not defined

# %%
#del data_groups

# %%
img_h, img_w = 155, 220

# %%
def visualize_sample_signature():
    '''Function to randomly select a signature from train set and
    print two genuine copies and one forged copy'''
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 10))
    k = np.random.randint(len(train))
    img_names = random.sample(train[k], 2)
    label1 = 0 if "F" in img_names[0] else 1
    label2 = 0 if "F" in img_names[1] else 1
    img1 = cv2.imread(img_names[0], 0)
    img2 = cv2.imread(img_names[1], 0)
    img1 = cv2.resize(img1, (img_w, img_h))
    img2 = cv2.resize(img2, (img_w, img_h))

    ax1.imshow(img1, cmap = 'gray')
    ax2.imshow(img2, cmap = 'gray')

    ax1.set_title('Genuine Copy' if label1 == 1 else 'Forged Copy')
    ax1.axis('off')
    ax2.set_title('Genuine Copy' if label2 == 1 else 'Forged Copy')
    ax2.axis('off')
    plt.show()

# %%
visualize_sample_signature()
